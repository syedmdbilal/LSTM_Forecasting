# %%
#import library packages
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Load the dataset
data = pd.read_excel("Data.xlsx")

pd.set_option('display.max_rows', None)

# %%
data.head()
# Out:
#         Date  Domestic Market (Contract) Blow Molding, Low  \
# 0 2000-01-01                                          41.0
# 1 2000-02-01                                          41.0
# 2 2000-03-01                                          45.0
# 3 2000-04-01                                          47.0
# 4 2000-05-01                                          47.0
#
#    Spot/Export Blow Molding  Spot, Domestic  WTISPLC  MCOILBRENTEU  GASREGM  \
# 0                       NaN             NaN    27.18         25.51    1.289
# 1                       NaN             NaN    29.35         27.78    1.377
# 2                       NaN             NaN    29.89         27.49    1.516
# 3                       NaN             NaN    25.74         22.76    1.465
# 4                       NaN             NaN    28.78         27.74    1.487
#
#     IMPCH   EXPCH  PRUBBUSDM  ...  Russia_import  South_Africa_import  \
# 0  6902.1   863.1  29.207387  ...            NaN                  NaN
# ...

# %%
#Checking the shape
data.shape
# Out:
# (276, 50)

# %%
data.columns
# Out:
# Index(['Date', 'Domestic Market (Contract) Blow Molding, Low',
#        'Spot/Export Blow Molding', 'Spot, Domestic', 'WTISPLC', 'MCOILBRENTEU',
#        'GASREGM', 'IMPCH', 'EXPCH', 'PRUBBUSDM', 'WPUFD4111',
#        'PCU325211325211', 'PCU32611332611301', 'WPU0915021625',
#        'PCU3252132521', 'MHHNGSP', 'WPU072205011', 'PCU32611132611115',
#        'PCU32611332611301.1', 'PCU32611132611112', 'WPU0915021622',
#        'Producer Price Index by Industry: Plastics Material and Resins Manufacturing: Thermoplastic Resins and Plastics Materials ',
#        'Australia _export', 'Canada_export', 'Saudi_export', 'Usa_export',
#        'India_export', 'Russia_export', 'South_Africa_export', 'Turkey',
#        'Brazil', 'France_export', 'Germeny_export', 'United Kingdome_export',
#        'China_export', 'Australia _import', 'Canada_import', 'Saudi_import',
#        'Usa_import', 'India_import', 'Russia_import', 'South_Africa_import',
# ...

# %%
data.rename(columns = {'Producer Price Index by Industry: Plastics Material and Resins Manufacturing: Thermoplastic Resins and Plastics Materials ':'Materials','Australia _export':'Australia_export','Australia _import':'Australia_import'}, inplace=True)

# %%
data
# Out:
#           Date  Domestic Market (Contract) Blow Molding, Low  \
# 0   2000-01-01                                          41.0
# 1   2000-02-01                                          41.0
# 2   2000-03-01                                          45.0
# 3   2000-04-01                                          47.0
# 4   2000-05-01                                          47.0
# 5   2000-06-01                                          47.0
# 6   2000-07-01                                          47.0
# 7   2000-08-01                                          46.0
# 8   2000-09-01                                          45.0
# 9   2000-10-01                                          43.0
# 10  2000-11-01                                          42.0
# 11  2000-12-01                                          41.0
# 12  2001-01-01                                          41.0
# 13  2001-02-01                                          46.0
# ...

# %%
data.isnull().sum()
# Out:
# Date                                              0
# Domestic Market (Contract) Blow Molding, Low      0
# Spot/Export Blow Molding                         91
# Spot, Domestic                                  151
# WTISPLC                                           0
# MCOILBRENTEU                                      0
# GASREGM                                           0
# IMPCH                                             1
# EXPCH                                             1
# PRUBBUSDM                                         1
# WPUFD4111                                         1
# PCU325211325211                                   1
# PCU32611332611301                                 1
# WPU0915021625                                   144
# PCU3252132521                                    48
# MHHNGSP                                           0
# WPU072205011                                    161
# PCU32611132611115                               161
# ...

# %%
df = data.fillna(data.mean())

# %%
df.shape
# Out:
# (276, 50)

# %%
df
# Out:
#           Date  Domestic Market (Contract) Blow Molding, Low  \
# 0   2000-01-01                                          41.0
# 1   2000-02-01                                          41.0
# 2   2000-03-01                                          45.0
# 3   2000-04-01                                          47.0
# 4   2000-05-01                                          47.0
# 5   2000-06-01                                          47.0
# 6   2000-07-01                                          47.0
# 7   2000-08-01                                          46.0
# 8   2000-09-01                                          45.0
# 9   2000-10-01                                          43.0
# 10  2000-11-01                                          42.0
# 11  2000-12-01                                          41.0
# 12  2001-01-01                                          41.0
# 13  2001-02-01                                          46.0
# ...

# %%
df.isnull().sum()
# Out:
# Date                                              0
# Domestic Market (Contract) Blow Molding, Low      0
# Spot/Export Blow Molding                          0
# Spot, Domestic                                    0
# WTISPLC                                           0
# MCOILBRENTEU                                      0
# GASREGM                                           0
# IMPCH                                             0
# EXPCH                                             0
# PRUBBUSDM                                         0
# WPUFD4111                                         0
# PCU325211325211                                   0
# PCU32611332611301                                 0
# WPU0915021625                                     0
# PCU3252132521                                     0
# MHHNGSP                                           0
# WPU072205011                                      0
# PCU32611132611115                                 0
# ...

# %%
del df['Date']
del df['Australia_export']
del df['Saudi_export']
del df['South_korea_import']

# %%
df.columns
# Out:
# Index(['Domestic Market (Contract) Blow Molding, Low',
#        'Spot/Export Blow Molding', 'Spot, Domestic', 'WTISPLC', 'MCOILBRENTEU',
#        'GASREGM', 'IMPCH', 'EXPCH', 'PRUBBUSDM', 'WPUFD4111',
#        'PCU325211325211', 'PCU32611332611301', 'WPU0915021625',
#        'PCU3252132521', 'MHHNGSP', 'WPU072205011', 'PCU32611132611115',
#        'PCU32611332611301.1', 'PCU32611132611112', 'WPU0915021622',
#        'Materials', 'Canada_export', 'Usa_export', 'India_export',
#        'Russia_export', 'South_Africa_export', 'Turkey', 'Brazil',
#        'France_export', 'Germeny_export', 'United Kingdome_export',
#        'China_export', 'Australia_import', 'Canada_import', 'Saudi_import',
#        'Usa_import', 'India_import', 'Russia_import', 'South_Africa_import',
#        'Turkey_import', 'Brazil_import', 'France_import', 'Germeny_import',
#        'United Kingdome_import', 'China_import', 'Japan_import'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Domestic Market (Contract) Blow Molding, Low  Spot/Export Blow Molding  \
# count                                    276.000000                276.000000
# mean                                      72.371377                 57.979730
# std                                       19.415335                 10.728782
# min                                       32.000000                 28.000000
# 25%                                       57.750000                 53.375000
# 50%                                       73.000000                 57.979730
# 75%                                       86.000000                 63.000000
# max                                      108.000000                 92.000000
#
#        Spot, Domestic     WTISPLC  MCOILBRENTEU     GASREGM         IMPCH  \
# count      276.000000  276.000000    276.000000  276.000000    276.000000
# mean        60.396000   62.505688     65.403768    2.570399  29591.894215
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 46 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Domestic Market (Contract) Blow Molding, Low  276 non-null    float64
#  1   Spot/Export Blow Molding                      276 non-null    float64
#  2   Spot, Domestic                                276 non-null    float64
#  3   WTISPLC                                       276 non-null    float64
#  4   MCOILBRENTEU                                  276 non-null    float64
#  5   GASREGM                                       276 non-null    float64
#  6   IMPCH                                         276 non-null    float64
#  7   EXPCH                                         276 non-null    float64
#  8   PRUBBUSDM                                     276 non-null    float64
# ...

# %%
df.dtypes.value_counts()
# Out:
# float64    46
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Domestic Market (Contract) Blow Molding, Low',
#        'Spot/Export Blow Molding', 'Spot, Domestic', 'WTISPLC', 'MCOILBRENTEU',
#        'GASREGM', 'IMPCH', 'EXPCH', 'PRUBBUSDM', 'WPUFD4111',
#        'PCU325211325211', 'PCU32611332611301', 'WPU0915021625',
#        'PCU3252132521', 'MHHNGSP', 'WPU072205011', 'PCU32611132611115',
#        'PCU32611332611301.1', 'PCU32611132611112', 'WPU0915021622',
#        'Materials', 'Canada_export', 'Usa_export', 'India_export',
#        'Russia_export', 'South_Africa_export', 'Turkey', 'Brazil',
#        'France_export', 'Germeny_export', 'United Kingdome_export',
#        'China_export', 'Australia_import', 'Canada_import', 'Saudi_import',
#        'Usa_import', 'India_import', 'Russia_import', 'South_Africa_import',
#        'Turkey_import', 'Brazil_import', 'France_import', 'Germeny_import',
#        'United Kingdome_import', 'China_import', 'Japan_import'],
#       dtype='object')

# %%
print("Domestic Market (Contract) Blow Molding, Low :", sorted(df['Domestic Market (Contract) Blow Molding, Low'].unique()))
# Out:
# Domestic Market (Contract) Blow Molding, Low : [32.0, 33.0, 34.0, 35.0, 36.0, 37.0, 38.0, 40.0, 41.0, 41.5, 42.0, 43.0, 44.0, 45.0, 46.0, 47.0, 49.0, 50.0, 51.0, 52.0, 53.0, 54.0, 55.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 67.0, 68.0, 69.0, 70.0, 70.5, 71.0, 72.0, 73.0, 75.0, 76.0, 77.0, 78.0, 79.0, 80.0, 80.5, 81.0, 82.0, 83.0, 84.0, 85.0, 86.0, 87.0, 88.0, 89.0, 90.0, 91.0, 92.0, 93.0, 95.0, 96.0, 97.0, 98.0, 100.0, 103.0, 104.0, 107.0, 108.0]

# %%
print("Minimum :", df['Domestic Market (Contract) Blow Molding, Low'].min())
print("Maximum :", df['Domestic Market (Contract) Blow Molding, Low'].max())
print("Mean :", df['Domestic Market (Contract) Blow Molding, Low'].mean())
print("Median :", df['Domestic Market (Contract) Blow Molding, Low'].median())
print("Mode :", df['Domestic Market (Contract) Blow Molding, Low'].mode())
print("Range :", df['Domestic Market (Contract) Blow Molding, Low'].info)
# Out:
# Minimum : 32.0
# Maximum : 108.0
# Mean : 72.3713768115942
# Median : 73.0
# Mode : 0    67.0
# 1    72.0
# Name: Domestic Market (Contract) Blow Molding, Low, dtype: float64
# Range : <bound method Series.info of 0       41.0
# 1       41.0
# 2       45.0
# 3       47.0
# 4       47.0
# 5       47.0
# 6       47.0
# 7       46.0
# 8       45.0
# 9       43.0
# 10      42.0
# 11      41.0
# 12      41.0
# 13      46.0
# 14      49.0
# 15      49.0
# 16      46.0
# 17      44.0
# 18      41.0
# 19      38.0
# 20      37.0
# 21      36.0
# 22      35.0
# 23      34.0
# 24      33.0
# 25      32.0
# 26      35.0
# 27      37.0
# 28      37.0
# 29      40.0
# 30      42.0
# 31      42.0
# 32      42.0
# 33      41.5
# 34      41.0
# 35      40.0
# 36      42.0
# 37      45.0
# 38      51.0
# 39      51.0
# 40      49.0
# 41      47.0
# 42      46.0
# 43      46.0
# 44      49.0
# 45      50.0
# 46      50.0
# 47      50.0
# 48      50.0
# 49      52.0
# 50      53.0
# 51      51.0
# ...

# %%
df.corr()
# Out:
#                                               Domestic Market (Contract) Blow Molding, Low  \
# Domestic Market (Contract) Blow Molding, Low                                      1.000000
# Spot/Export Blow Molding                                                          0.511035
# Spot, Domestic                                                                    0.443208
# WTISPLC                                                                           0.880024
# MCOILBRENTEU                                                                      0.881459
# GASREGM                                                                           0.902080
# IMPCH                                                                             0.731635
# EXPCH                                                                             0.714458
# PRUBBUSDM                                                                         0.636563
# ...

# %%
df
# Out:
#      Domestic Market (Contract) Blow Molding, Low  Spot/Export Blow Molding  \
# 0                                            41.0                  57.97973
# 1                                            41.0                  57.97973
# 2                                            45.0                  57.97973
# 3                                            47.0                  57.97973
# 4                                            47.0                  57.97973
# 5                                            47.0                  57.97973
# 6                                            47.0                  57.97973
# 7                                            46.0                  57.97973
# 8                                            45.0                  57.97973
# 9                                            43.0                  57.97973
# 10                                           42.0                  57.97973
# ...

# %%
df['Domestic Market (Contract) Blow Molding, Low'].hist(figsize=(5,3), color='magenta', alpha=1)
plt.xlabel('Domestic Market (Contract) Blow Molding, Low')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
fig, ax = plt.subplots(figsize=(25,25))
sns.heatmap(df.corr(),annot = True, ax=ax)
plt.show()

# %%
# Splitting the data into x and y ( input and output )

X=df.drop(columns='Domestic Market (Contract) Blow Molding, Low', axis=1)
y=df.loc[:,'Domestic Market (Contract) Blow Molding, Low']

# %%
### Train test split

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state=24)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((193, 45), (83, 45), (193,), (83,))

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, explained_variance_score, median_absolute_error

# %%
MLP = MLPRegressor()
MLP.fit(X_train,y_train)
predictMLP = MLP.predict(X_test)

LR = LinearRegression()
LR.fit(X_train,y_train)
predictLR = LR.predict(X_test)

RFR = RandomForestRegressor()
RFR.fit(X_train,y_train)
predictRFR = RFR.predict(X_test)

LIR = LinearRegression()
LIR.fit(X_train,y_train)
predictLIR = LIR.predict(X_test)

LA = Lasso()
LA.fit(X_train,y_train)
predictLA = LA.predict(X_test)

KNR = KNeighborsRegressor()
KNR.fit(X_train,y_train)
predictKNR = KNR.predict(X_test)

SV = SVR()
SV.fit(X_train,y_train)
predictSV = SV.predict(X_test)

# %%
MAE = (mean_absolute_error(y_test,predictMLP))
print("MEAN ABSOLUTE ERROR OF MLP:", MAE)
print('')

MAE = (mean_absolute_error(y_test,predictLR))
print("MEAN ABSOLUTE ERROR OF LR:", MAE)
print('')

MAE = (mean_absolute_error(y_test,predictRFR))
print("MEAN ABSOLUTE ERROR OF RFR:", MAE)
print('')

MAE = (mean_absolute_error(y_test,predictLIR))
print("MEAN ABSOLUTE ERROR OF LIR:", MAE)
print('')

MAE = (mean_absolute_error(y_test,predictLA))
print("MEAN ABSOLUTE ERROR OF LA:", MAE)
print('')

MAE = (mean_absolute_error(y_test,predictKNR))
print("MEAN ABSOLUTE ERROR OF KNR:", MAE)
print('')

MAE = (mean_absolute_error(y_test,predictSV))
print("MEAN ABSOLUTE ERROR OF SVR:", MAE)
# Out:
# MEAN ABSOLUTE ERROR OF MLP: 26467511.26009519
#
# MEAN ABSOLUTE ERROR OF LR: 3.380466929178682
#
# MEAN ABSOLUTE ERROR OF RFR: 3.5053012048192764
#
# MEAN ABSOLUTE ERROR OF LIR: 3.380466929178682
#
# MEAN ABSOLUTE ERROR OF LA: 3.6376815855554376
#
# MEAN ABSOLUTE ERROR OF KNR: 6.266265060240964
#
# MEAN ABSOLUTE ERROR OF SVR: 14.99747648293798

# %%
MSE = (mean_squared_error(y_test,predictMLP))
print("MEAN SQUARED ERROR OF MLP:", MSE)
print('')

MSE = (mean_squared_error(y_test,predictLR))
print("MEAN SQUARED ERROR OF LR:", MSE)
print('')

MSE = (mean_squared_error(y_test,predictRFR))
print("MEAN SQUARED ERROR OF RFR:", MSE)
print('')

MSE = (mean_squared_error(y_test,predictLIR))
print("MEAN SQUARED ERROR OF LIR:", MSE)
print('')

MSE = (mean_squared_error(y_test,predictLA))
print("MEAN SQUARED ERROR OF LA:", MSE)
print('')

MSE = (mean_squared_error(y_test,predictKNR))
print("MEAN SQUARED ERROR OF KNR:", MSE)
print('')

MSE = (mean_squared_error(y_test,predictSV))
print("MEAN SQUARED ERROR OF SVR:", MSE)
# Out:
# MEAN SQUARED ERROR OF MLP: 746863460969838.9
#
# MEAN SQUARED ERROR OF LR: 20.531763937269687
#
# MEAN SQUARED ERROR OF RFR: 30.086942168674693
#
# MEAN SQUARED ERROR OF LIR: 20.531763937269687
#
# MEAN SQUARED ERROR OF LA: 23.094100673764355
#
# MEAN SQUARED ERROR OF KNR: 68.36831325301203
#
# MEAN SQUARED ERROR OF SVR: 338.9419310387306

# %%
MEDIAN_AE = (median_absolute_error(y_test,predictMLP))
print("MEDIAN ABSOLUTE ERROR OF MLP:", MEDIAN_AE)
print('')

MEDIAN_AE = (median_absolute_error(y_test,predictLR))
print("MEDIAN ABSOLUTE ERROR OF LR:", MEDIAN_AE)
print('')

MEDIAN_AE = (median_absolute_error(y_test,predictRFR))
print("MEDIAN ABSOLUTE ERROR OF RFR:", MEDIAN_AE)
print('')

MEDIAN_AE = (median_absolute_error(y_test,predictLIR))
print("MEDIAN ABSOLUTE ERROR OF LIR:", MEDIAN_AE)
print('')

MEDIAN_AE = (median_absolute_error(y_test,predictLA))
print("MEDIAN ABSOLUTE ERROR OF LA:", MEDIAN_AE)
print('')

MEDIAN_AE = (median_absolute_error(y_test,predictKNR))
print("MEDIAN ABSOLUTE ERROR OF KNR:", MEDIAN_AE)
print('')

MEDIAN_AE = (median_absolute_error(y_test,predictSV))
print("MEDIAN ABSOLUTE ERROR OF SVR:", MEDIAN_AE)
# Out:
# MEDIAN ABSOLUTE ERROR OF MLP: 27018147.005770978
#
# MEDIAN ABSOLUTE ERROR OF LR: 2.5190108540335245
#
# MEDIAN ABSOLUTE ERROR OF RFR: 2.25
#
# MEDIAN ABSOLUTE ERROR OF LIR: 2.5190108540335245
#
# MEDIAN ABSOLUTE ERROR OF LA: 3.2204396146310543
#
# MEDIAN ABSOLUTE ERROR OF KNR: 4.399999999999999
#
# MEDIAN ABSOLUTE ERROR OF SVR: 12.072507341852955

# %%
EV = (explained_variance_score(y_test,predictMLP))
print("EXPLAINED VARIENCE SCORE OF MLP:", EV)
print('')

EV = (explained_variance_score(y_test,predictLR))
print("EXPLAINED VARIENCE SCORE OF LR:", EV)
print('')

EV = (explained_variance_score(y_test,predictRFR))
print("EXPLAINED VARIENCE SCORE OF RFR:", EV)
print('')

EV = (explained_variance_score(y_test,predictLIR))
print("EXPLAINED VARIENCE SCORE OF LIR:", EV)
print('')

EV = (explained_variance_score(y_test,predictLA))
print("EXPLAINED VARIENCE SCORE OF LA:", EV)
print('')

EV = (explained_variance_score(y_test,predictKNR))
print("EXPLAINED VARIENCE SCORE OF KNR:", EV)
print('')

EV = (explained_variance_score(y_test,predictSV))
print("EXPLAINED VARIENCE SCORE OF SVR:", EV)
# Out:
# EXPLAINED VARIENCE SCORE OF MLP: -126639289687.27385
#
# EXPLAINED VARIENCE SCORE OF LR: 0.9439598317833646
#
# EXPLAINED VARIENCE SCORE OF RFR: 0.9179063219655139
#
# EXPLAINED VARIENCE SCORE OF LIR: 0.9439598317833646
#
# EXPLAINED VARIENCE SCORE OF LA: 0.9369337524439163
#
# EXPLAINED VARIENCE SCORE OF KNR: 0.8157347596519213
#
# EXPLAINED VARIENCE SCORE OF SVR: 0.07443055899175521

# %%
EV = (explained_variance_score(y_test,predictMLP))
print("EXPLAINED VARIENCE SCORE OF MLP:", EV)
print('')

EV = (explained_variance_score(y_test,predictLR))
print("EXPLAINED VARIENCE SCORE OF LR:", EV)
print('')

EV = (explained_variance_score(y_test,predictRFR))
print("EXPLAINED VARIENCE SCORE OF RFR:", EV)
print('')

EV = (explained_variance_score(y_test,predictLIR))
print("EXPLAINED VARIENCE SCORE OF LIR:", EV)
print('')

EV = (explained_variance_score(y_test,predictLA))
print("EXPLAINED VARIENCE SCORE OF LA:", EV)
print('')

EV = (explained_variance_score(y_test,predictKNR))
print("EXPLAINED VARIENCE SCORE OF KNR:", EV)
print('')

EV = (explained_variance_score(y_test,predictSV))
print("EXPLAINED VARIENCE SCORE OF SVR:", EV)
# Out:
# EXPLAINED VARIENCE SCORE OF MLP: -126639289687.27385
#
# EXPLAINED VARIENCE SCORE OF LR: 0.9439598317833646
#
# EXPLAINED VARIENCE SCORE OF RFR: 0.9179063219655139
#
# EXPLAINED VARIENCE SCORE OF LIR: 0.9439598317833646
#
# EXPLAINED VARIENCE SCORE OF LA: 0.9369337524439163
#
# EXPLAINED VARIENCE SCORE OF KNR: 0.8157347596519213
#
# EXPLAINED VARIENCE SCORE OF SVR: 0.07443055899175521

# %%
R2_SCORE = (r2_score(y_test,predictMLP))
print("r2_schore of MLP:", R2_SCORE)
print('')

R2_SCORE = (r2_score(y_test,predictLR))
print("r2_schore of LR:", R2_SCORE)
print('')

R2_SCORE = (r2_score(y_test,predictRFR))
print("r2_schore of RFR:", R2_SCORE)
print('')

R2_SCORE = (r2_score(y_test,predictLIR))
print("r2_schore of LIR:", R2_SCORE)
print('')

R2_SCORE = (r2_score(y_test,predictLA))
print("r2_schore of LA:", R2_SCORE)
print('')

R2_SCORE = (r2_score(y_test,predictKNR))
print("r2_schore of KNR:", R2_SCORE)
print('')

R2_SCORE = (r2_score(y_test,predictSV))
print("r2_schore of SVR:", R2_SCORE)
# Out:
# r2_schore of MLP: -2041300731859.934
#
# r2_schore of LR: 0.9438833107498386
#
# r2_schore of RFR: 0.9177674363817171
#
# r2_schore of LIR: 0.9438833107498386
#
# r2_schore of LA: 0.9368800228279891
#
# r2_schore of KNR: 0.813138150180429
#
# r2_schore of SVR: 0.07361593109766573
